# %%
import pandas as pd
import numpy as np
from sklearn import tree, metrics
from sklearn.model_selection import train_test_split

# %%
clf = tree.DecisionTreeClassifier()

# %% [markdown]
# ## Reading text file using numpy

# %%
data = np.loadtxt("../data/wifi_db/clean_dataset.txt")
data.shape
# Out:
# (2000, 8)

# %%
X, y = data[:,0:7], data[:,7]

# %%
X
# Out:
# array([[-64., -56., -61., ..., -71., -82., -81.],
#        [-68., -57., -61., ..., -71., -85., -85.],
#        [-63., -60., -60., ..., -76., -85., -84.],
#        ...,
#        [-62., -59., -46., ..., -45., -87., -88.],
#        [-62., -58., -52., ..., -41., -90., -85.],
#        [-59., -50., -45., ..., -45., -88., -87.]])

# %%
y
# Out:
# array([1., 1., 1., ..., 4., 4., 4.])

# %% [markdown]
# ## Split data in train & test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
print(X.shape, X_train.shape, X_test.shape) 
print(y.shape, y_train.shape, y_test.shape)
# Out:
# (2000, 7) (1600, 7) (400, 7)
# (2000,) (1600,) (400,)

# %% [markdown]
# ## Fitting the data in DecisionTreeClassifier

# %%
clf = clf.fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# ## Evaluation Model

# %%
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.965

# %%
sum(y_test == y_pred)
# Out:
# 386

# %% [markdown]
# ## Visualizing the tree

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.7220203488372093, 0.96875, 'x[4] <= -55.5\ngini = 0.75\nsamples = 1600\nvalue = [390.0, 397.0, 398.0, 415.0]'),
#  Text(0.5748546511627907, 0.90625, 'x[0] <= -55.5\ngini = 0.673\nsamples = 1194\nvalue = [390.0, 397.0, 396.0, 11.0]'),
#  Text(0.6484375, 0.9375, 'True  '),
#  Text(0.3502906976744186, 0.84375, 'x[4] <= -59.5\ngini = 0.077\nsamples = 405\nvalue = [389, 0, 5, 11]'),
#  Text(0.2819767441860465, 0.78125, 'x[3] <= -55.5\ngini = 0.03\nsamples = 395\nvalue = [389, 0, 3, 3]'),
#  Text(0.21511627906976744, 0.71875, 'x[2] <= -50.5\ngini = 0.02\nsamples = 392\nvalue = [388.0, 0.0, 1.0, 3.0]'),
#  Text(0.1511627906976744, 0.65625, 'x[2] <= -51.5\ngini = 0.015\nsamples = 390\nvalue = [387, 0, 1, 2]'),
#  Text(0.09302325581395349, 0.59375, 'x[4] <= -61.5\ngini = 0.01\nsamples = 386\nvalue = [384, 0, 0, 2]'),
#  Text(0.046511627906976744, 0.53125, 'x[2] <= -54.5\ngini = 0.005\nsamples = 382\nvalue = [381, 0, 0, 1]'),
#  Text(0.023255813953488372, 0.46875, 'gini = 0.0\nsamples = 364\nvalue = [364, 0, 0, 0]'),
#  Text(0.06976744186046512, 0.46875, 'x[5] <= -87.5\ngini = 0.105\nsamples = 18\nvalue = [17, 0, 0, 1]'),
#  Text(0.046511627906976744, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.09302325581395349, 0.40625, 'gini = 0.0\nsamples = 17\nvalue = [17, 0, 0, 0]'),
#  Text(0.13953488372093023, 0.53125, 'x[5] <= -82.0\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 1]'),
#  Text(0.11627906976744186, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.16279069767441862, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.20930232558139536, 0.59375, 'x[4] <= -66.5\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 1, 0]'),
#  Text(0.18604651162790697, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.23255813953488372, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.27906976744186046, 0.65625, 'x[4] <= -64.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]'),
#  Text(0.2558139534883721, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.3023255813953488, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.3488372093023256, 0.71875, 'x[0] <= -57.5\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2, 0]'),
#  Text(0.32558139534883723, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.37209302325581395, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.4186046511627907, 0.78125, 'x[1] <= -52.5\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 2, 8]'),
#  Text(0.3953488372093023, 0.71875, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6]'),
#  Text(0.4418604651162791, 0.71875, 'x[3] <= -58.5\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2]'),
#  Text(0.4186046511627907, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.46511627906976744, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.7994186046511628, 0.84375, 'x[0] <= -44.5\ngini = 0.501\nsamples = 789\nvalue = [1.0, 397.0, 391.0, 0.0]'),
#  Text(0.6686046511627907, 0.78125, 'x[4] <= -70.5\ngini = 0.201\nsamples = 433\nvalue = [1, 48, 384, 0]'),
#  Text(0.5581395348837209, 0.71875, 'x[3] <= -48.5\ngini = 0.353\nsamples = 35\nvalue = [0, 27, 8, 0]'),
#  Text(0.5116279069767442, 0.65625, 'x[2] <= -58.0\ngini = 0.375\nsamples = 8\nvalue = [0, 2, 6, 0]'),
#  Text(0.4883720930232558, 0.59375, 'x[5] <= -85.0\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]'),
#  Text(0.46511627906976744, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.5116279069767442, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.5348837209302325, 0.59375, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]'),
#  Text(0.6046511627906976, 0.65625, 'x[1] <= -58.5\ngini = 0.137\nsamples = 27\nvalue = [0, 25, 2, 0]'),
#  Text(0.5813953488372093, 0.59375, 'x[1] <= -59.5\ngini = 0.444\nsamples = 6\nvalue = [0, 4, 2, 0]'),
#  Text(0.5581395348837209, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.6046511627906976, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.627906976744186, 0.59375, 'gini = 0.0\nsamples = 21\nvalue = [0, 21, 0, 0]'),
#  Text(0.7790697674418605, 0.71875, 'x[3] <= -40.5\ngini = 0.105\nsamples = 398\nvalue = [1, 21, 376, 0]'),
#  Text(0.7209302325581395, 0.65625, 'x[6] <= -73.5\ngini = 0.074\nsamples = 390\nvalue = [1.0, 14.0, 375.0, 0.0]'),
#  Text(0.6744186046511628, 0.59375, 'x[3] <= -65.0\ngini = 0.056\nsamples = 383\nvalue = [1, 10, 372, 0]'),
#  Text(0.6511627906976745, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.6976744186046512, 0.53125, 'x[5] <= -72.5\ngini = 0.051\nsamples = 382\nvalue = [0, 10, 372, 0]'),
#  Text(0.6744186046511628, 0.46875, 'x[2] <= -63.5\ngini = 0.046\nsamples = 381\nvalue = [0, 9, 372, 0]'),
#  Text(0.6511627906976745, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.6976744186046512, 0.40625, 'x[0] <= -45.5\ngini = 0.041\nsamples = 380\nvalue = [0, 8, 372, 0]'),
#  Text(0.5697674418604651, 0.34375, 'x[0] <= -46.5\ngini = 0.022\nsamples = 357\nvalue = [0, 4, 353, 0]'),
#  Text(0.45348837209302323, 0.28125, 'x[4] <= -69.5\ngini = 0.012\nsamples = 326\nvalue = [0, 2, 324, 0]'),
#  Text(0.4069767441860465, 0.21875, 'x[5] <= -77.5\ngini = 0.198\nsamples = 9\nvalue = [0, 1, 8, 0]'),
#  Text(0.38372093023255816, 0.15625, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0]'),
#  Text(0.43023255813953487, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.5, 0.21875, 'x[3] <= -46.5\ngini = 0.006\nsamples = 317\nvalue = [0, 1, 316, 0]'),
#  Text(0.47674418604651164, 0.15625, 'gini = 0.0\nsamples = 278\nvalue = [0, 0, 278, 0]'),
#  Text(0.5232558139534884, 0.15625, 'x[5] <= -85.5\ngini = 0.05\nsamples = 39\nvalue = [0, 1, 38, 0]'),
#  Text(0.5, 0.09375, 'x[6] <= -80.5\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0]'),
#  Text(0.47674418604651164, 0.03125, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]'),
#  Text(0.5232558139534884, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.5465116279069767, 0.09375, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33, 0]'),
#  Text(0.686046511627907, 0.28125, 'x[5] <= -77.5\ngini = 0.121\nsamples = 31\nvalue = [0, 2, 29, 0]'),
#  Text(0.6395348837209303, 0.21875, 'x[5] <= -85.5\ngini = 0.067\nsamples = 29\nvalue = [0, 1, 28, 0]'),
#  Text(0.6162790697674418, 0.15625, 'x[2] <= -54.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0]'),
#  Text(0.5930232558139535, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.6395348837209303, 0.09375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.6627906976744186, 0.15625, 'gini = 0.0\nsamples = 26\nvalue = [0, 0, 26, 0]'),
#  Text(0.7325581395348837, 0.21875, 'x[2] <= -53.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]'),
#  Text(0.7093023255813954, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.7558139534883721, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.8255813953488372, 0.34375, 'x[4] <= -68.5\ngini = 0.287\nsamples = 23\nvalue = [0, 4, 19, 0]'),
#  Text(0.8023255813953488, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.8488372093023255, 0.28125, 'x[6] <= -76.0\ngini = 0.172\nsamples = 21\nvalue = [0, 2, 19, 0]'),
#  Text(0.8255813953488372, 0.21875, 'x[4] <= -66.0\ngini = 0.095\nsamples = 20\nvalue = [0, 1, 19, 0]'),
#  Text(0.8023255813953488, 0.15625, 'x[1] <= -56.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0]'),
#  Text(0.7790697674418605, 0.09375, 'x[3] <= -50.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]'),
#  Text(0.7558139534883721, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.8023255813953488, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.8255813953488372, 0.09375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.8488372093023255, 0.15625, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0]'),
#  Text(0.872093023255814, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.7209302325581395, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.7674418604651163, 0.59375, 'x[5] <= -79.0\ngini = 0.49\nsamples = 7\nvalue = [0, 4, 3, 0]'),
#  Text(0.7441860465116279, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.7906976744186046, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.8372093023255814, 0.65625, 'x[1] <= -59.0\ngini = 0.219\nsamples = 8\nvalue = [0, 7, 1, 0]'),
#  Text(0.813953488372093, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.8604651162790697, 0.59375, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]'),
#  Text(0.9302325581395349, 0.78125, 'x[3] <= -51.5\ngini = 0.039\nsamples = 356\nvalue = [0, 349, 7, 0]'),
#  Text(0.9069767441860465, 0.71875, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]'),
#  Text(0.9534883720930233, 0.71875, 'x[6] <= -83.5\ngini = 0.017\nsamples = 352\nvalue = [0, 349, 3, 0]'),
#  Text(0.9302325581395349, 0.65625, 'x[3] <= -45.5\ngini = 0.469\nsamples = 8\nvalue = [0, 5, 3, 0]'),
#  Text(0.9069767441860465, 0.59375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.9534883720930233, 0.59375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]'),
#  Text(0.9767441860465116, 0.65625, 'gini = 0.0\nsamples = 344\nvalue = [0, 344, 0, 0]'),
#  Text(0.8691860465116279, 0.90625, 'x[3] <= -50.5\ngini = 0.01\nsamples = 406\nvalue = [0, 0, 2, 404]'),
#  Text(0.7956031976744187, 0.9375, '  False'),
#  Text(0.8459302325581395, 0.84375, 'gini = 0.0\nsamples = 404\nvalue = [0, 0, 0, 404]'),
#  Text(0.8924418604651163, 0.84375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]')]
