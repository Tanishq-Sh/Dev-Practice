# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
X = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y = np.array([0, 0, 0, 1, 1, 1])

# %%
lr_model = LogisticRegression()
lr_model.fit(X, y)
# Out:
# LogisticRegression()

# %%
w = lr_model.coef_
b = lr_model.intercept_
print(w)
print(b)
# Out:
# [[0.90411349 0.73587543]]
# [-2.33371631]

# %%
y_pred = lr_model.predict(X)
x0 = -b[0]/w[0, 0]
x1 = -b[0]/w[0, 1]
print(x0, x1)
# Out:
# 2.581220528435747 3.1713469675428563

# %%
pos = y == 1
neg = y == 0
pos = pos.reshape(-1)
neg = neg.reshape(-1)

fig, ax = plt.subplots(1, 1, figsize=(7,4))
ax.scatter(X[pos, 0], X[pos, 1], marker = 'x', color = 'red')
ax.scatter(X[neg, 0], X[neg, 1], marker = 'o', color = 'blue', facecolor = 'none')
ax.plot([x0,0], [0,x1])

# %% [markdown]
# ## Performed logictic regression using sklearn!
